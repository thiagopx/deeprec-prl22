# %%
# %load_ext autoreload
# %autoreload 2

import os
PROJECT_DIR = os.path.expanduser("/dados/thiagopx/deeprec-prl22")
os.chdir(PROJECT_DIR)

# %%
import json
import pandas as pd

# %%
from notebooks.utils import replace_underscore
from notebooks.results.utils import get_dataframe, plot_sensitivity_analysis
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ## Sensitivity analysis
#
# * $w_{load} = 0.25$
# * $\lambda = 20, 30, 40, \ldots, 250$

# %%
df = get_dataframe(".results/sensitivity_analysis.json")

# %%
plot_sensitivity_analysis(df)
